# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
data= {'animal':pd.Series['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age':pd.Series[2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits':pd.Series [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority':pd.Series['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-a1513422b1f8> in <module>
# ----> 1 data= {'animal':pd.Series['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#       2         'age':pd.Series[2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#       3         'visits':pd.Series [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#       4         'priority':pd.Series['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# TypeError: 'type' object is not subscriptable

# %%
df=pd.DataFrame(data ,index='labels')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7ba90488e713> in <module>
# ----> 1 df=pd.DataFrame(data ,index='labels')
#       2 df
#
# NameError: name 'data' is not defined

# %%
df=pd.DataFrame.dict(data,index='labels')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b01c0981f86b> in <module>
# ----> 1 df=pd.DataFrame.from_records(data,index='labels')
#       2 df
#
# NameError: name 'data' is not defined

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.info()

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df[df.animal,df.age].size()

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
df[[]]

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df[(df['visits']>3)]

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
df[(df['age']=='np.nan')]

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df[(df['animal']=='cat')&(df['age']<3)]

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[(df['age']>2)&(df['age']<4)]

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df[5,2]==1.5

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
total_visits=np.sum(df.visits)
print('Total visits:',total_visits)

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df.age

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df[(df.age.sort(ascending=False))&(df.visits.sort(ascending=True))

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
data_ny=pd.read_csv("C:/Users/ASUS/Desktop/DATA SCIENCE/Virtual Competition/ny-flights.csv")
data_ny
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
data_ny.airline_id.value_counts()
# Out:
# 20409    4902
# 19790    3803
# 20398    2434
# 19805    2427
# 20366    2080
# 19393    1917
# 20355    1568
# 19977    1106
# 21171     301
# 20437     206
# 20436      33
# 19690      29
# 20304      11
# Name: airline_id, dtype: int64

# %% [markdown]
# ### Therefore maximum Airline id is 20409 which occurs 4902 times

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20817 entries, 0 to 20816
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fl_date         20817 non-null  object
#  1   unique_carrier  20817 non-null  object
#  2   airline_id      20817 non-null  int64
#  3   tail_num        20512 non-null  object
#  4   fl_num          20817 non-null  int64
#  5   origin          20817 non-null  object
#  6   dest            20817 non-null  object
#  7   dep_time        18462 non-null  float64
#  8   dep_delay       18462 non-null  float64
#  9   arr_time        18412 non-null  float64
#  10  arr_delay       18383 non-null  float64
#  11  cancelled       20817 non-null  float64
#  12  arr             18412 non-null  object
#  13  dep             18462 non-null  object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 2.2+ MB

# %%
data_ny[['dep_delay','arr_delay']].groupby(['dep_delay'],['arr_delay']).size()
data_final
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-eda091a7cd46> in <module>
# ----> 1 data_ny[['dep_delay','arr_delay']].groupby(['dep_delay'],['arr_delay']).size()
#       2 data_final
#
# D:\JEEVAN DOC\softwares\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6713         if level is None and by is None:
#    6714             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6715         axis = self._get_axis_number(axis)
#    6716
#    6717         return DataFrameGroupBy(
#
# D:\JEEVAN DOC\softwares\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
# ...

# %%
plt.figure(figsize=(110,100))
sns.barplot(x=data_ny.dep_delay,y=data_ny.arr_delay,data=data_ny);
plt.xticks(rotation=90)
plt.show()
