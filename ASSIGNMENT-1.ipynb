# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###  1) Read the dataset to python environment.

# %%
iris=pd.read_excel(r"C:\Users\ASUS\Desktop\DATA SCIENCE\Assignments\iris.xls")

# %% [markdown]
# ### 2) Display the columns in the dataset.

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 3) Calculate the mean of each column of the dataset.

# %%
mn=np.mean(iris)

# %%
mn
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4) Check for the null values present in the dataset.

# %%
iris.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### 5) Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
plt.bar(iris['SW'],iris['Classification']);
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(iris['SL'])
plt.figure(figsize=(15,10))
plt.show()

# %%
iris.plot (kind = 'barh', x = 'SL', y = 'SW', color = 'green')
plt.xticks(rotation=90);

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(iris.PL,vert=False);

# %%
plt.pie(iris.SL,iris.PL);

# %%
plt.pie(iris.PW,iris.SW);
plt.pie(iris.SL,iris.PL);

# %%
plt.pie(iris.SL);

# %%
sns.histplot(x=iris['Classification'],y=iris['SL'])
plt.show()
