# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/ASUS/Desktop/DATA SCIENCE/Assignments/Assignment 3/StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### 1. Find out how many males and females participated in the test.

# %%
data["gender"].value_counts(dropna=False)
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.groupby(['gender']).size()
# Out:
# gender
# female    518
# male      482
# dtype: int64

# %% [markdown]
# ### 2. What do you think about the students' parental level of education?

# %%
data.groupby(['parental level of education']).size()
# Out:
# parental level of education
# associate's degree    222
# bachelor's degree     118
# high school           196
# master's degree        59
# some college          226
# some high school      179
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='parental level of education',data=data);

# %% [markdown]
# ### Conclusion
# Majority of parents have attained graduation in some college

# %% [markdown]
# ### 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
data.groupby(['math score','reading score','writing score','gender']).size()
# Out:
# math score  reading score  writing score  gender
# 0           17             10             female    1
# 8           24             23             female    1
# 11          38             32             female    1
# 13          41             51             female    1
# 18          32             28             female    1
#                                                    ..
# 100         96             86             male      1
#             97             99             male      1
#             100            93             male      1
#                            100            female    2
#                                           male      1
# Length: 985, dtype: int64

# %%
data.groupby('gender')[['math score', 'reading score', 'writing score']].mean().T.plot(kind='bar', figsize=(6,4));

# %%
data.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean().T.plot(kind='bar', figsize=(6,4));

# %% [markdown]
# ### 4. What do you think about the scoring variation for math, reading and writing
# based on
# ● Gender
# ● Test preparation course

# %%
sns.histplot(data,x='math score',palette='rocket',kde=True);

# %%
plt.figure(figsize=(6,6))
sns.histplot(data,x='math score',palette='rocket',kde=True)
sns.stripplot(data=data,y='math score',x='gender',palette='rocket');

# %% [markdown]
# ### Math Score Vs. Gender

# %%
sns.stripplot(data=data,y='reading score',x='gender',palette='rocket');

# %% [markdown]
# ### Reading Score Vs. Gender

# %%
sns.stripplot(data=data,y='writing score',x='gender');

# %% [markdown]
# ### Writing Score Vs. Gender

# %%
sns.stripplot(data=data,y='math score',x='test preparation course');

# %% [markdown]
# ### Math Score Vs. Test Preparation Course

# %%
sns.stripplot(data=data,y='math score',x='test preparation course');

# %% [markdown]
# ### Math Score Vs. Test Preparation Course

# %%
sns.stripplot(data=data,y='reading score',x='test preparation course');

# %% [markdown]
# ### Reading Score Vs. Test Preparation Course

# %%
sns.stripplot(data=data,y='writing score',x='test preparation course');

# %% [markdown]
# ### Writing Score Vs. Test Preparation Course

# %% [markdown]
# ### 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
top_25=(25/100)*1000
top_25
# Out:
# 250.0

# %%
new_data=data[(data['math score']>75)].sort_values(by=['math score'],ascending=[False]).head(250)
new_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### list of top 25% of Students list is Displayed

# %% [markdown]
# # THANK YOU
